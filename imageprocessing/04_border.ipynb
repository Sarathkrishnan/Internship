# %%
import cv2 
import matplotlib.pyplot as plt
# path 
path = r'/home/sarathkrishnan/Desktop/Internship/imageprocessing/salt_and_pepper.jpeg'
   
# Reading an image in default mode
image = cv2.imread(path)
   
# Window name in which image is displayed
window_name = 'Image'
  
# Using cv2.copyMakeBorder() method
#image = cv2.copyMakeBorder(image, 100, 100, 50, 50, cv2.BORDER_REFLECT)
#image = cv2.copyMakeBorder(image, 100, 100, 50, 50, cv2.BORDER_CONSTANT)
image = cv2.copyMakeBorder(image, 100, 100, 50, 50, cv2.BORDER_REPLICATE )

# Displaying the image 
#cv2.imshow(window_name, image)
plt.imshow(image)
